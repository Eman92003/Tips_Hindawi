# %%
import requests

URL = "ADD_NGROK_LINK/generate"  
headers = {"Authorization": "Bearer secret123"}
payload = {
    "prompt": "who is messi?",
    "max_length": 300
}

res = requests.post(URL, headers=headers, json=payload)
answer = res.json()["response"]

# %%
print(answer)
# Out:
# who is messi? Lionel Messi is an Argentine professional footballer who plays as a forward and captains both the Argentina national team and Ligue 1 club Paris Saint-Germain. He is widely regarded as one of the greatest players of all time and has won numerous awards, including a record seven Ballon d'Or awards. Here are some key facts about him:
#
# 1. **Full Name**: Lionel Andrés Messi Cuccittini
# 2. **Date of Birth**: June 24, 1987
# 3. **Place of Birth**: Rosario, Argentina
# 4. **Height**: 1.70 m (5 ft 7 in)
# 5. **Position**: Forward
# 6. **Shirt Number**: 30 (Argentina), 30 (Paris Saint-Germain)
# 7. **Previous Clubs**: Barcelona (2004-2021)
# 8. **International Debut**: August 17, 2005
# 9. **Honors**:
#    - Ballon d'Or: 7 (2009, 2010, 2011, 2012, 2015, 2019, 2021)
#    - FIFA World Player of the Year: 6 (2009, 2010, 2011, 2012, 2015, 2019)
#    - UEFA Best Player in
